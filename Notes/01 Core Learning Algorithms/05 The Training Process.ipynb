# %%
# %tensorflow_version 2.x
from __future__ import absolute_import, division, print_function, unicode_literals

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib

import tensorflow.compat.v2.feature_column as fc
# import tensorflow.feature_column as fc
# import tensorflow.keras.utils.

import tensorflow as tf

# %%
dftrain = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv')
dfeval = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/eval.csv')
y_train = dftrain.pop('survived')
y_eval = dfeval.pop('survived')

# %%
categorical_columns = ['sex', 'n_siblings_spouses', 'parch', 'class', 'deck', 'embark_town', 'alone']
numerical_columns = ['age', 'fare']

feature_columns = []
for feature_name in categorical_columns:
    vocabulary = dftrain[feature_name].unique() # get all unique values from the given feature column
    feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))

for feature_name in numerical_columns:
    feature_columns.append(tf.feature_column.numeric_column(feature_name, dtype=tf.float32))

feature_columns
# Out:
# [VocabularyListCategoricalColumn(key='sex', vocabulary_list=('male', 'female'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='n_siblings_spouses', vocabulary_list=(1, 0, 3, 4, 2, 5, 8), dtype=tf.int64, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='parch', vocabulary_list=(0, 1, 2, 5, 3, 4), dtype=tf.int64, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='class', vocabulary_list=('Third', 'First', 'Second'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='deck', vocabulary_list=('unknown', 'C', 'G', 'A', 'B', 'D', 'F', 'E'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='embark_town', vocabulary_list=('Southampton', 'Cherbourg', 'Queenstown', 'unknown'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='alone', vocabulary_list=('n', 'y'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='fare', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %% [markdown]
# ## Training Process
# - Could do all data at once, but that breaks for large datasets
# - Instead, do batches. In this case, batches of 32. Batches of 1 would be slower
# - Epochs: How many times the model will see the same data
#     - First time: kinda works, not a great fit
#     - Second time: improved fit
#     - Multiple times: best fit
#     - Overfitting: in some models, if shown the same data too many times, the model essentially memorizes the train data and doesn't work well for other data
#
# ### Input Function
# - Input Function: function that decides how we divide the training data and send it to the training function

# %%
def make_input_fn(data_df, label_df, num_epochs=10, shuffle=True, batch_size=32):
    def input_function(): # inner function to return
        ds = tf.data.Dataset.from_tensor_slices((dict(data_df), label_df)) # create tf.data.Dataset object with data and its labels
        if shuffle:
            ds = ds.shuffle(1000) # randomize order of data
        ds = ds.batch(batch_size).repeat(num_epochs) # split dataset into batches of 32 and repeat process for number of epochs
        return ds
    return input_function

train_input_fn = make_input_fn(dftrain, y_train) # calling the input function that was returned to us to get a dataset object we can feed to the model
eval_input_fn = make_input_fn(dfeval, y_eval, num_epochs=1, shuffle=False)

# %% [markdown]
# # Creating the Model

# %%
linear_est = tf.estimator.LinearClassifier(feature_columns)

linear_est.train(train_input_fn)
result = linear_est.evaluate(eval_input_fn)
# clear_output()
result['accuracy']
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\miraf\AppData\Local\Temp\tmpxjx7cwd_
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\miraf\\AppData\\Local\\Temp\\tmpxjx7cwd_', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\miraf\AppData\Local\Temp\tmpxjx7cwd_\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 0.6931472, step = 0
# INFO:tensorflow:global_step/sec: 570.058
# INFO:tensorflow:loss = 0.44704422, step = 100 (0.176 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 200...
# INFO:tensorflow:Saving checkpoints for 200 into C:\Users\miraf\AppData\Local\Temp\tmpxjx7cwd_\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 200...
# INFO:tensorflow:Loss for final step: 0.4891309.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-12-13T15:20:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\miraf\AppData\Local\Temp\tmpxjx7cwd_\model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.38930s
# INFO:tensorflow:Finished evaluation at 2023-12-13-15:20:32
# INFO:tensorflow:Saving dict for global step 200: accuracy = 0.75, accuracy_baseline = 0.625, auc = 0.8249159, auc_precision_recall = 0.78838, average_loss = 0.5348224, global_step = 200, label/mean = 0.375, loss = 0.5323756, precision = 0.6386555, prediction/mean = 0.49597764, recall = 0.7676768
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 200: C:\Users\miraf\AppData\Local\Temp\tmpxjx7cwd_\model.ckpt-200
# 0.75

# %%
result
# Out:
# {'accuracy': 0.75,
#  'accuracy_baseline': 0.625,
#  'auc': 0.8249159,
#  'auc_precision_recall': 0.78838,
#  'average_loss': 0.5348224,
#  'label/mean': 0.375,
#  'loss': 0.5323756,
#  'precision': 0.6386555,
#  'prediction/mean': 0.49597764,
#  'recall': 0.7676768,
#  'global_step': 200}

# %% [markdown]
# - so far, created and trained the model
# ### Using the model
# - designed to use with large batches of data, not for singular datapoints
# -

# %%
result = list(linear_est.predict(eval_input_fn))
result
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\miraf\AppData\Local\Temp\tmpxjx7cwd_\model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([-1.7670368], dtype=float32),
#   'logistic': array([0.14591122], dtype=float32),
#   'probabilities': array([0.8540888 , 0.14591123], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6961032], dtype=float32),
#   'logistic': array([0.66732323], dtype=float32),
#   'probabilities': array([0.33267674, 0.66732323], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.2766676], dtype=float32),
#   'logistic': array([0.90692616], dtype=float32),
#   'probabilities': array([0.09307386, 0.90692616], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.7146524], dtype=float32),
#   'logistic': array([0.84743875], dtype=float32),
#   'probabilities': array([0.15256126, 0.84743875], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.24808541], dtype=float32),
#   'logistic': array([0.43829483], dtype=float32),
#   'probabilities': array([0.56170523, 0.43829483], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.4641917], dtype=float32),
#   'logistic': array([0.81217295], dtype=float32),
#   'probabilities': array([0.18782705, 0.81217295], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6698673], dtype=float32),
#   'logistic': array([0.6614734], dtype=float32),
#   'probabilities': array([0.33852658, 0.66147345], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6253427], dtype=float32),
#   'logistic': array([0.16446936], dtype=float32),
#   'probabilities': array([0.83553064, 0.16446936], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0246133], dtype=float32),
#   'logistic': array([0.73587024], dtype=float32),
#   'probabilities': array([0.2641298 , 0.73587024], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.4215641], dtype=float32),
#   'logistic': array([0.8055835], dtype=float32),
#   'probabilities': array([0.19441651, 0.80558354], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3286287], dtype=float32),
#   'logistic': array([0.7906137], dtype=float32),
#   'probabilities': array([0.2093863, 0.7906138], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6289152], dtype=float32),
#   'logistic': array([0.16397904], dtype=float32),
#   'probabilities': array([0.836021  , 0.16397904], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.1826746], dtype=float32),
#   'logistic': array([0.8986829], dtype=float32),
#   'probabilities': array([0.10131714, 0.8986829 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.25125137], dtype=float32),
#   'logistic': array([0.5624845], dtype=float32),
#   'probabilities': array([0.43751556, 0.5624845 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.3573937], dtype=float32),
#   'logistic': array([0.91352016], dtype=float32),
#   'probabilities': array([0.08647988, 0.91352016], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.9328779], dtype=float32),
#   'logistic': array([0.7176588], dtype=float32),
#   'probabilities': array([0.2823412 , 0.71765876], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9634831], dtype=float32),
#   'logistic': array([0.27618137], dtype=float32),
#   'probabilities': array([0.72381866, 0.2761814 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.020657], dtype=float32),
#   'logistic': array([0.88294894], dtype=float32),
#   'probabilities': array([0.11705106, 0.88294894], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.25845876], dtype=float32),
#   'logistic': array([0.5642573], dtype=float32),
#   'probabilities': array([0.43574262, 0.5642574 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7063106], dtype=float32),
#   'logistic': array([0.15364286], dtype=float32),
#   'probabilities': array([0.84635717, 0.15364288], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6180197], dtype=float32),
#   'logistic': array([0.16547817], dtype=float32),
#   'probabilities': array([0.8345219 , 0.16547817], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7029016], dtype=float32),
#   'logistic': array([0.1540867], dtype=float32),
#   'probabilities': array([0.84591335, 0.15408671], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1749104], dtype=float32),
#   'logistic': array([0.7640314], dtype=float32),
#   'probabilities': array([0.23596855, 0.76403147], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7996033], dtype=float32),
#   'logistic': array([0.14189936], dtype=float32),
#   'probabilities': array([0.8581006 , 0.14189936], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2801899], dtype=float32),
#   'logistic': array([0.78248215], dtype=float32),
#   'probabilities': array([0.2175179, 0.7824821], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.76018536], dtype=float32),
#   'logistic': array([0.681394], dtype=float32),
#   'probabilities': array([0.31860602, 0.681394  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.25409797], dtype=float32),
#   'logistic': array([0.4368151], dtype=float32),
#   'probabilities': array([0.5631849, 0.4368151], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.76049113], dtype=float32),
#   'logistic': array([0.6814603], dtype=float32),
#   'probabilities': array([0.31853965, 0.6814604 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8676949], dtype=float32),
#   'logistic': array([0.29573417], dtype=float32),
#   'probabilities': array([0.7042659 , 0.29573417], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.4770997], dtype=float32),
#   'logistic': array([0.92252076], dtype=float32),
#   'probabilities': array([0.07747926, 0.9225207 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1921265], dtype=float32),
#   'logistic': array([0.23287882], dtype=float32),
#   'probabilities': array([0.76712114, 0.2328788 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.184775], dtype=float32),
#   'logistic': array([0.8988739], dtype=float32),
#   'probabilities': array([0.10112604, 0.8988739 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8305556], dtype=float32),
#   'logistic': array([0.3035276], dtype=float32),
#   'probabilities': array([0.69647247, 0.30352762], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.325802], dtype=float32),
#   'logistic': array([0.7901454], dtype=float32),
#   'probabilities': array([0.2098546, 0.7901454], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.28264973], dtype=float32),
#   'logistic': array([0.4298043], dtype=float32),
#   'probabilities': array([0.5701957 , 0.42980427], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6897012], dtype=float32),
#   'logistic': array([0.15581514], dtype=float32),
#   'probabilities': array([0.8441848 , 0.15581514], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.70932186], dtype=float32),
#   'logistic': array([0.32974872], dtype=float32),
#   'probabilities': array([0.6702513 , 0.32974872], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.002613], dtype=float32),
#   'logistic': array([0.268428], dtype=float32),
#   'probabilities': array([0.731572  , 0.26842803], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([3.277409], dtype=float32),
#   'logistic': array([0.96364564], dtype=float32),
#   'probabilities': array([0.03635437, 0.9636456 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7164317], dtype=float32),
#   'logistic': array([0.15233135], dtype=float32),
#   'probabilities': array([0.84766865, 0.15233135], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.8628951], dtype=float32),
#   'logistic': array([0.865634], dtype=float32),
#   'probabilities': array([0.13436596, 0.8656341 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7319559], dtype=float32),
#   'logistic': array([0.15033756], dtype=float32),
#   'probabilities': array([0.8496625 , 0.15033756], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.9403], dtype=float32),
#   'logistic': array([0.71916026], dtype=float32),
#   'probabilities': array([0.28083977, 0.71916026], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.33128193], dtype=float32),
#   'logistic': array([0.41792873], dtype=float32),
#   'probabilities': array([0.58207124, 0.41792876], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.00444303], dtype=float32),
#   'logistic': array([0.4988892], dtype=float32),
#   'probabilities': array([0.50111073, 0.49888924], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.5749032], dtype=float32),
#   'logistic': array([0.8284815], dtype=float32),
#   'probabilities': array([0.1715185, 0.8284815], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.627129], dtype=float32),
#   'logistic': array([0.16422404], dtype=float32),
#   'probabilities': array([0.835776  , 0.16422406], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.46269432], dtype=float32),
#   'logistic': array([0.6136531], dtype=float32),
#   'probabilities': array([0.3863469, 0.6136532], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.00276849], dtype=float32),
#   'logistic': array([0.49930787], dtype=float32),
#   'probabilities': array([0.5006921, 0.4993079], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4650642], dtype=float32),
#   'logistic': array([0.61421484], dtype=float32),
#   'probabilities': array([0.38578513, 0.61421484], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3402497], dtype=float32),
#   'logistic': array([0.207469], dtype=float32),
#   'probabilities': array([0.792531, 0.207469], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7698295], dtype=float32),
#   'logistic': array([0.31651598], dtype=float32),
#   'probabilities': array([0.683484  , 0.31651598], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8854227], dtype=float32),
#   'logistic': array([0.13176726], dtype=float32),
#   'probabilities': array([0.8682328 , 0.13176724], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3282249], dtype=float32),
#   'logistic': array([0.20945314], dtype=float32),
#   'probabilities': array([0.79054683, 0.20945312], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5949796], dtype=float32),
#   'logistic': array([0.16868444], dtype=float32),
#   'probabilities': array([0.8313155 , 0.16868442], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6699954], dtype=float32),
#   'logistic': array([0.15842478], dtype=float32),
#   'probabilities': array([0.8415752 , 0.15842481], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8811607], dtype=float32),
#   'logistic': array([0.2929373], dtype=float32),
#   'probabilities': array([0.70706266, 0.29293728], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([4.384364], dtype=float32),
#   'logistic': array([0.9876828], dtype=float32),
#   'probabilities': array([0.01231721, 0.98768276], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.85079765], dtype=float32),
#   'logistic': array([0.29926553], dtype=float32),
#   'probabilities': array([0.7007345 , 0.29926556], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6983932], dtype=float32),
#   'logistic': array([0.15467523], dtype=float32),
#   'probabilities': array([0.84532475, 0.15467525], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6438855], dtype=float32),
#   'logistic': array([0.6556313], dtype=float32),
#   'probabilities': array([0.34436873, 0.65563124], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.73142993], dtype=float32),
#   'logistic': array([0.675119], dtype=float32),
#   'probabilities': array([0.32488102, 0.675119  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8561592], dtype=float32),
#   'logistic': array([0.2981424], dtype=float32),
#   'probabilities': array([0.7018576, 0.2981424], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.9304796], dtype=float32),
#   'logistic': array([0.8733025], dtype=float32),
#   'probabilities': array([0.1266975, 0.8733025], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.90676427], dtype=float32),
#   'logistic': array([0.28766242], dtype=float32),
#   'probabilities': array([0.7123376 , 0.28766242], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1362127], dtype=float32),
#   'logistic': array([0.7569836], dtype=float32),
#   'probabilities': array([0.2430164 , 0.75698364], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.77951133], dtype=float32),
#   'logistic': array([0.68557477], dtype=float32),
#   'probabilities': array([0.3144252 , 0.68557477], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.87421954], dtype=float32),
#   'logistic': array([0.29437706], dtype=float32),
#   'probabilities': array([0.705623  , 0.29437706], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.56978554], dtype=float32),
#   'logistic': array([0.3612863], dtype=float32),
#   'probabilities': array([0.6387137, 0.3612863], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3530257], dtype=float32),
#   'logistic': array([0.79462385], dtype=float32),
#   'probabilities': array([0.20537615, 0.79462385], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([3.8726375], dtype=float32),
#   'logistic': array([0.9796205], dtype=float32),
#   'probabilities': array([0.02037947, 0.9796205 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2612203], dtype=float32),
#   'logistic': array([0.77923614], dtype=float32),
#   'probabilities': array([0.22076388, 0.77923614], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8518177], dtype=float32),
#   'logistic': array([0.1356596], dtype=float32),
#   'probabilities': array([0.86434036, 0.1356596 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6051005], dtype=float32),
#   'logistic': array([0.16726996], dtype=float32),
#   'probabilities': array([0.83273005, 0.16726995], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1811706], dtype=float32),
#   'logistic': array([0.2348418], dtype=float32),
#   'probabilities': array([0.76515824, 0.2348418 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6957115], dtype=float32),
#   'logistic': array([0.1550262], dtype=float32),
#   'probabilities': array([0.84497374, 0.15502621], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6376671], dtype=float32),
#   'logistic': array([0.16278277], dtype=float32),
#   'probabilities': array([0.8372173 , 0.16278277], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.002613], dtype=float32),
#   'logistic': array([0.268428], dtype=float32),
#   'probabilities': array([0.731572  , 0.26842803], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3893548], dtype=float32),
#   'logistic': array([0.80048925], dtype=float32),
#   'probabilities': array([0.19951077, 0.8004892 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([4.670354], dtype=float32),
#   'logistic': array([0.990718], dtype=float32),
#   'probabilities': array([0.00928199, 0.99071807], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1616954], dtype=float32),
#   'logistic': array([0.7616406], dtype=float32),
#   'probabilities': array([0.23835939, 0.76164067], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.25125137], dtype=float32),
#   'logistic': array([0.5624845], dtype=float32),
#   'probabilities': array([0.43751556, 0.5624845 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1055026], dtype=float32),
#   'logistic': array([0.2487103], dtype=float32),
#   'probabilities': array([0.7512897 , 0.24871033], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([4.423737], dtype=float32),
#   'logistic': array([0.9881527], dtype=float32),
#   'probabilities': array([0.0118473, 0.9881527], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5844082], dtype=float32),
#   'logistic': array([0.1701721], dtype=float32),
#   'probabilities': array([0.82982796, 0.17017208], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.6286987], dtype=float32),
#   'logistic': array([0.8359913], dtype=float32),
#   'probabilities': array([0.1640087, 0.8359913], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1272234], dtype=float32),
#   'logistic': array([0.7553261], dtype=float32),
#   'probabilities': array([0.24467388, 0.7553261 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1097752], dtype=float32),
#   'logistic': array([0.24791281], dtype=float32),
#   'probabilities': array([0.7520872 , 0.24791282], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.1386564], dtype=float32),
#   'logistic': array([0.89460397], dtype=float32),
#   'probabilities': array([0.10539602, 0.894604  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.5376418], dtype=float32),
#   'logistic': array([0.92673886], dtype=float32),
#   'probabilities': array([0.07326113, 0.9267389 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([4.111046], dtype=float32),
#   'logistic': array([0.9838737], dtype=float32),
#   'probabilities': array([0.0161263 , 0.98387367], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.37492362], dtype=float32),
#   'logistic': array([0.40735185], dtype=float32),
#   'probabilities': array([0.59264815, 0.40735185], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7611138], dtype=float32),
#   'logistic': array([0.14665091], dtype=float32),
#   'probabilities': array([0.85334915, 0.14665093], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([5.3713913], dtype=float32),
#   'logistic': array([0.99537385], dtype=float32),
#   'probabilities': array([0.00462616, 0.9953739 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.19398084], dtype=float32),
#   'logistic': array([0.5483437], dtype=float32),
#   'probabilities': array([0.45165625, 0.5483437 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([4.81742], dtype=float32),
#   'logistic': array([0.9919773], dtype=float32),
#   'probabilities': array([0.00802274, 0.9919773 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1831925], dtype=float32),
#   'logistic': array([0.23447867], dtype=float32),
#   'probabilities': array([0.76552135, 0.23447865], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8291312], dtype=float32),
#   'logistic': array([0.1383418], dtype=float32),
#   'probabilities': array([0.8616582, 0.1383418], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6287941], dtype=float32),
#   'logistic': array([0.16399562], dtype=float32),
#   'probabilities': array([0.8360043 , 0.16399562], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.10492209], dtype=float32),
#   'logistic': array([0.47379348], dtype=float32),
#   'probabilities': array([0.5262065, 0.4737935], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7278637], dtype=float32),
#   'logistic': array([0.15086104], dtype=float32),
#   'probabilities': array([0.849139  , 0.15086104], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.6617087], dtype=float32),
#   'logistic': array([0.8404673], dtype=float32),
#   'probabilities': array([0.15953277, 0.8404673 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.8540267], dtype=float32),
#   'logistic': array([0.86459917], dtype=float32),
#   'probabilities': array([0.13540082, 0.8645992 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.72047234], dtype=float32),
#   'logistic': array([0.672711], dtype=float32),
#   'probabilities': array([0.327289, 0.672711], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1590735], dtype=float32),
#   'logistic': array([0.76116425], dtype=float32),
#   'probabilities': array([0.23883569, 0.76116437], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1160451], dtype=float32),
#   'logistic': array([0.2467456], dtype=float32),
#   'probabilities': array([0.75325435, 0.24674562], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.6435003], dtype=float32),
#   'logistic': array([0.83801067], dtype=float32),
#   'probabilities': array([0.16198933, 0.8380106 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.840525], dtype=float32),
#   'logistic': array([0.94482684], dtype=float32),
#   'probabilities': array([0.05517317, 0.94482684], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.8640822], dtype=float32),
#   'logistic': array([0.86577207], dtype=float32),
#   'probabilities': array([0.13422793, 0.865772  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0265355], dtype=float32),
#   'logistic': array([0.11644489], dtype=float32),
#   'probabilities': array([0.88355505, 0.11644489], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.9400489], dtype=float32),
#   'logistic': array([0.8743575], dtype=float32),
#   'probabilities': array([0.12564246, 0.8743575 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.270069], dtype=float32),
#   'logistic': array([0.7807546], dtype=float32),
#   'probabilities': array([0.21924543, 0.78075457], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1995], dtype=float32),
#   'logistic': array([0.76843584], dtype=float32),
#   'probabilities': array([0.23156418, 0.76843584], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9332598], dtype=float32),
#   'logistic': array([0.1263902], dtype=float32),
#   'probabilities': array([0.87360984, 0.12639019], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([3.723596], dtype=float32),
#   'logistic': array([0.97642237], dtype=float32),
#   'probabilities': array([0.02357765, 0.9764223 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1156926], dtype=float32),
#   'logistic': array([0.75318885], dtype=float32),
#   'probabilities': array([0.24681118, 0.7531889 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7088114], dtype=float32),
#   'logistic': array([0.15331794], dtype=float32),
#   'probabilities': array([0.846682  , 0.15331794], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3483164], dtype=float32),
#   'logistic': array([0.7938542], dtype=float32),
#   'probabilities': array([0.20614575, 0.79385424], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7076215], dtype=float32),
#   'logistic': array([0.15347248], dtype=float32),
#   'probabilities': array([0.8465275 , 0.15347248], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.194896], dtype=float32),
#   'logistic': array([0.8997902], dtype=float32),
#   'probabilities': array([0.10020977, 0.8997903 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.95823383], dtype=float32),
#   'logistic': array([0.72276807], dtype=float32),
#   'probabilities': array([0.27723196, 0.72276807], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6056782], dtype=float32),
#   'logistic': array([0.16718951], dtype=float32),
#   'probabilities': array([0.8328105, 0.1671895], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7568867], dtype=float32),
#   'logistic': array([0.6806774], dtype=float32),
#   'probabilities': array([0.31932256, 0.6806774 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.137149], dtype=float32),
#   'logistic': array([0.8944618], dtype=float32),
#   'probabilities': array([0.10553822, 0.8944618 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.461824], dtype=float32),
#   'logistic': array([0.1881885], dtype=float32),
#   'probabilities': array([0.8118115, 0.1881885], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6961895], dtype=float32),
#   'logistic': array([0.15496358], dtype=float32),
#   'probabilities': array([0.8450364, 0.1549636], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.6866635], dtype=float32),
#   'logistic': array([0.84378487], dtype=float32),
#   'probabilities': array([0.15621513, 0.84378487], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4773403], dtype=float32),
#   'logistic': array([0.18582948], dtype=float32),
#   'probabilities': array([0.8141705 , 0.18582948], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.063339], dtype=float32),
#   'logistic': array([0.25667188], dtype=float32),
#   'probabilities': array([0.7433281, 0.2566719], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0466862], dtype=float32),
#   'logistic': array([0.25986198], dtype=float32),
#   'probabilities': array([0.74013805, 0.25986195], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7886473], dtype=float32),
#   'logistic': array([0.14323865], dtype=float32),
#   'probabilities': array([0.8567614 , 0.14323866], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1960484], dtype=float32),
#   'logistic': array([0.7678211], dtype=float32),
#   'probabilities': array([0.23217893, 0.7678211 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6430258], dtype=float32),
#   'logistic': array([0.16205378], dtype=float32),
#   'probabilities': array([0.83794624, 0.16205376], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.918852], dtype=float32),
#   'logistic': array([0.12798963], dtype=float32),
#   'probabilities': array([0.87201035, 0.12798962], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7164317], dtype=float32),
#   'logistic': array([0.15233135], dtype=float32),
#   'probabilities': array([0.84766865, 0.15233135], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6367744], dtype=float32),
#   'logistic': array([0.16290444], dtype=float32),
#   'probabilities': array([0.83709556, 0.16290444], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.44249365], dtype=float32),
#   'logistic': array([0.39114693], dtype=float32),
#   'probabilities': array([0.60885304, 0.39114696], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0477446], dtype=float32),
#   'logistic': array([0.25965843], dtype=float32),
#   'probabilities': array([0.7403416 , 0.25965843], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([4.2540026], dtype=float32),
#   'logistic': array([0.9859918], dtype=float32),
#   'probabilities': array([0.01400824, 0.9859918 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5954465], dtype=float32),
#   'logistic': array([0.168619], dtype=float32),
#   'probabilities': array([0.831381  , 0.16861899], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6593381], dtype=float32),
#   'logistic': array([0.15985087], dtype=float32),
#   'probabilities': array([0.8401491 , 0.15985087], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3269025], dtype=float32),
#   'logistic': array([0.7903278], dtype=float32),
#   'probabilities': array([0.20967218, 0.7903278 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([4.0143313], dtype=float32),
#   'logistic': array([0.9822652], dtype=float32),
#   'probabilities': array([0.01773482, 0.98226523], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4893447], dtype=float32),
#   'logistic': array([0.1840201], dtype=float32),
# ...
#  {'logits': array([0.4005083], dtype=float32),
#   'logistic': array([0.5988097], dtype=float32),
#   'probabilities': array([0.40119025, 0.5988098 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7283388], dtype=float32),
#   'logistic': array([0.15080018], dtype=float32),
#   'probabilities': array([0.84919983, 0.15080017], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2526051], dtype=float32),
#   'logistic': array([0.2222495], dtype=float32),
#   'probabilities': array([0.77775043, 0.2222495 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.9248083], dtype=float32),
#   'logistic': array([0.87267363], dtype=float32),
#   'probabilities': array([0.12732634, 0.8726737 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.8857702], dtype=float32),
#   'logistic': array([0.7080165], dtype=float32),
#   'probabilities': array([0.29198346, 0.7080165 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5077034], dtype=float32),
#   'logistic': array([0.1812794], dtype=float32),
#   'probabilities': array([0.8187206 , 0.18127938], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4150798], dtype=float32),
#   'logistic': array([0.39769468], dtype=float32),
#   'probabilities': array([0.6023053 , 0.39769474], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.78114325], dtype=float32),
#   'logistic': array([0.31407356], dtype=float32),
#   'probabilities': array([0.6859265 , 0.31407356], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([3.8422744], dtype=float32),
#   'logistic': array([0.97900546], dtype=float32),
#   'probabilities': array([0.02099455, 0.97900546], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([4.084686], dtype=float32),
#   'logistic': array([0.98345006], dtype=float32),
#   'probabilities': array([0.01654992, 0.9834501 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5786673], dtype=float32),
#   'logistic': array([0.1709843], dtype=float32),
#   'probabilities': array([0.82901573, 0.17098431], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3033262], dtype=float32),
#   'logistic': array([0.78639424], dtype=float32),
#   'probabilities': array([0.21360575, 0.7863943 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6349853], dtype=float32),
#   'logistic': array([0.16314857], dtype=float32),
#   'probabilities': array([0.8368514 , 0.16314857], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1511071], dtype=float32),
#   'logistic': array([0.24028692], dtype=float32),
#   'probabilities': array([0.75971305, 0.24028695], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.8647476], dtype=float32),
#   'logistic': array([0.8658494], dtype=float32),
#   'probabilities': array([0.13415062, 0.8658493 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4775189], dtype=float32),
#   'logistic': array([0.18580246], dtype=float32),
#   'probabilities': array([0.81419754, 0.18580246], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([5.472368], dtype=float32),
#   'logistic': array([0.9958163], dtype=float32),
#   'probabilities': array([0.0041837, 0.9958163], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.8067371], dtype=float32),
#   'logistic': array([0.85896707], dtype=float32),
#   'probabilities': array([0.14103295, 0.85896707], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6772586], dtype=float32),
#   'logistic': array([0.15745881], dtype=float32),
#   'probabilities': array([0.8425412 , 0.15745883], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.20307], dtype=float32),
#   'logistic': array([0.7690705], dtype=float32),
#   'probabilities': array([0.23092952, 0.7690705 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5603658], dtype=float32),
#   'logistic': array([0.17359418], dtype=float32),
#   'probabilities': array([0.8264059 , 0.17359416], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9061117], dtype=float32),
#   'logistic': array([0.28779614], dtype=float32),
#   'probabilities': array([0.71220386, 0.28779614], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7014302], dtype=float32),
#   'logistic': array([0.15427856], dtype=float32),
#   'probabilities': array([0.8457215 , 0.15427859], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2070597], dtype=float32),
#   'logistic': array([0.7697783], dtype=float32),
#   'probabilities': array([0.23022169, 0.76977825], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7197013], dtype=float32),
#   'logistic': array([0.67254126], dtype=float32),
#   'probabilities': array([0.32745874, 0.6725412 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8708686], dtype=float32),
#   'logistic': array([0.13344125], dtype=float32),
#   'probabilities': array([0.8665588 , 0.13344125], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.80295545], dtype=float32),
#   'logistic': array([0.30939367], dtype=float32),
#   'probabilities': array([0.69060636, 0.30939367], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.0504222], dtype=float32),
#   'logistic': array([0.88599026], dtype=float32),
#   'probabilities': array([0.11400972, 0.88599026], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.09409509], dtype=float32),
#   'logistic': array([0.47649357], dtype=float32),
#   'probabilities': array([0.52350646, 0.4764936 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([3.6170642], dtype=float32),
#   'logistic': array([0.97384125], dtype=float32),
#   'probabilities': array([0.02615876, 0.97384125], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.3559675], dtype=float32),
#   'logistic': array([0.41193607], dtype=float32),
#   'probabilities': array([0.58806396, 0.41193607], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0443923], dtype=float32),
#   'logistic': array([0.26030338], dtype=float32),
#   'probabilities': array([0.7396966 , 0.26030338], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6170079], dtype=float32),
#   'logistic': array([0.16561794], dtype=float32),
#   'probabilities': array([0.8343821 , 0.16561794], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.576106], dtype=float32),
#   'logistic': array([0.17134768], dtype=float32),
#   'probabilities': array([0.8286523 , 0.17134766], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.165686], dtype=float32),
#   'logistic': array([0.10287451], dtype=float32),
#   'probabilities': array([0.89712554, 0.10287451], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.1095738], dtype=float32),
#   'logistic': array([0.8918302], dtype=float32),
#   'probabilities': array([0.10816978, 0.89183027], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.0329597], dtype=float32),
#   'logistic': array([0.8842144], dtype=float32),
#   'probabilities': array([0.11578557, 0.88421446], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1510471], dtype=float32),
#   'logistic': array([0.24029788], dtype=float32),
#   'probabilities': array([0.75970215, 0.24029788], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7474282], dtype=float32),
#   'logistic': array([0.32138193], dtype=float32),
#   'probabilities': array([0.678618  , 0.32138193], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.9458861], dtype=float32),
#   'logistic': array([0.9500687], dtype=float32),
#   'probabilities': array([0.0499313, 0.9500687], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.9614344], dtype=float32),
#   'logistic': array([0.7234089], dtype=float32),
#   'probabilities': array([0.27659112, 0.72340894], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6754693], dtype=float32),
#   'logistic': array([0.15769634], dtype=float32),
#   'probabilities': array([0.84230363, 0.15769635], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([3.6101031], dtype=float32),
#   'logistic': array([0.97366333], dtype=float32),
#   'probabilities': array([0.02633667, 0.97366333], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.1085808], dtype=float32),
#   'logistic': array([0.8917344], dtype=float32),
#   'probabilities': array([0.10826561, 0.8917344 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7489983], dtype=float32),
#   'logistic': array([0.1481736], dtype=float32),
#   'probabilities': array([0.8518264, 0.1481736], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1391599], dtype=float32),
#   'logistic': array([0.7575254], dtype=float32),
#   'probabilities': array([0.24247465, 0.7575254 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.85079765], dtype=float32),
#   'logistic': array([0.29926553], dtype=float32),
#   'probabilities': array([0.7007345 , 0.29926556], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.40074244], dtype=float32),
#   'logistic': array([0.598866], dtype=float32),
#   'probabilities': array([0.40113398, 0.598866  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)}]

# %% [markdown]
# - we get a dictionary of prediction info for each data point
# - need to look at each dict to figure out what the prediction was
# - the probabilities value is what we want

# %%
result[0]
# dictionary for 1 prediction
# Out:
# {'logits': array([-1.7670368], dtype=float32),
#  'logistic': array([0.14591122], dtype=float32),
#  'probabilities': array([0.8540888 , 0.14591123], dtype=float32),
#  'class_ids': array([0], dtype=int64),
#  'classes': array([b'0'], dtype=object),
#  'all_class_ids': array([0, 1]),
#  'all_classes': array([b'0', b'1'], dtype=object)}

# %% [markdown]
# - not survival prediction pct is 0.854, survive is 0.146

# %%
result[0]['probabilities'][1] # survival chance prediction
# Out:
# 0.14591123

# %% [markdown]
# Does 14% survival make sense?

# %%
dfeval.loc[0]
# Out:
# sex                          male
# age                          35.0
# n_siblings_spouses              0
# parch                           0
# fare                         8.05
# class                       Third
# deck                      unknown
# embark_town           Southampton
# alone                           y
# Name: 0, dtype: object

# %% [markdown]
# 14% survival for 35yo third class male with no sibs or spouses sounds right
# - we can check some more people

# %%
y_eval.loc[0] # yes, this guy died
# Out:
# 0
